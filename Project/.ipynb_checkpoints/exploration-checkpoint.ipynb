# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
db_file = "./data/database.sqlite"
try:
    conn = sqlite3.connect(db_file)
except Exception as e:
    print(e)
# Out:
# unable to open database file

# %%
cur  = conn.cursor()
tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
# conn.tables

# %%
# tables.fetchall()

# %%
players = pd.read_sql_query("SELECT * from Player", conn)
match = pd.read_sql_query("SELECT * from Match",conn)
league = pd.read_sql_query("SELECT * from League",conn)
team = pd.read_sql_query("SELECT * from Team",conn)
player_attr = pd.read_sql_query("SELECT * from Player_Attributes",conn)
team_attr = pd.read_sql_query("SELECT * from Team_Attributes",conn)

# %%
num_matches = g.merge(league,left_on='league_id',right_on='id')
num_matches['no_of_matches'] = num_matches['count']
num_matches = num_matches[['name', 'no_of_matches']]

# %%
num_matches
# Out:
#                         name  no_of_matches
# 0     Belgium Jupiler League           1728
# 1     England Premier League           3040
# 2             France Ligue 1           3040
# 3      Germany 1. Bundesliga           2448
# 4              Italy Serie A           3017
# 5     Netherlands Eredivisie           2448
# 6         Poland Ekstraklasa           1920
# 7   Portugal Liga ZON Sagres           2052
# 8    Scotland Premier League           1824
# 9            Spain LIGA BBVA           3040
# 10  Switzerland Super League           1422

# %%
barca = team_attr.iloc[123]
barca = barca.drop(['id','team_fifa_api_id','team_api_id','date'])
barca = pd.DataFrame(barca)

# %%
# barca.to_html()

# %% [markdown]
# <table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>FC Barcelona</th>    </tr>  </thead>  <tbody>    <tr>      <th>buildUpPlaySpeed</th>      <td>36</td>    </tr>    <tr>      <th>buildUpPlaySpeedClass</th>      <td>Balanced</td>    </tr>    <tr>      <th>buildUpPlayDribbling</th>      <td>35</td>    </tr>    <tr>      <th>buildUpPlayDribblingClass</th>      <td>Normal</td>    </tr>    <tr>      <th>buildUpPlayPassing</th>      <td>51</td>    </tr>    <tr>      <th>buildUpPlayPassingClass</th>      <td>Mixed</td>    </tr>    <tr>      <th>buildUpPlayPositioningClass</th>      <td>Free Form</td>    </tr>    <tr>      <th>chanceCreationPassing</th>      <td>36</td>    </tr>    <tr>      <th>chanceCreationPassingClass</th>      <td>Normal</td>    </tr>    <tr>      <th>chanceCreationCrossing</th>      <td>49</td>    </tr>    <tr>      <th>chanceCreationCrossingClass</th>      <td>Normal</td>    </tr>    <tr>      <th>chanceCreationShooting</th>      <td>56</td>    </tr>    <tr>      <th>chanceCreationShootingClass</th>      <td>Normal</td>    </tr>    <tr>      <th>chanceCreationPositioningClass</th>      <td>Free Form</td>    </tr>    <tr>      <th>defencePressure</th>      <td>61</td>    </tr>    <tr>      <th>defencePressureClass</th>      <td>Medium</td>    </tr>    <tr>      <th>defenceAggression</th>      <td>65</td>    </tr>    <tr>      <th>defenceAggressionClass</th>      <td>Press</td>    </tr>    <tr>      <th>defenceTeamWidth</th>      <td>65</td>    </tr>    <tr>      <th>defenceTeamWidthClass</th>      <td>Normal</td>    </tr>    <tr>      <th>defenceDefenderLineClass</th>      <td>Cover</td>    </tr>  </tbody></table>

# %%
players[players['player_name'] == 'Lionel Messi']
# Out:
#         id  player_api_id   player_name  player_fifa_api_id  \
# 6169  6176          30981  Lionel Messi              158023
#
#                  birthday  height  weight
# 6169  1987-06-24 00:00:00  170.18     159

# %%
# player_attr[player_attr['player_api_id'] == 30981]
messi = player_attr.iloc[102482].drop(['id','player_fifa_api_id','player_api_id','date','preferred_foot','attacking_work_rate',
                              'defensive_work_rate'])

# %%
messi.plot(kind='bar',figsize=(8,8))
plt.savefig('messi.png',bbox_inches='tight')
plt.show()

# %%
match.shape
# Out:
# (25979, 115)

# %%
g = match.groupby('league_id').count()
g['count'] = g['id']
g = pd.DataFrame(g['count'])

# %%
# league

# %%
g['league_id'] = g.index

# %%
keys = match.keys()
for k in keys:
#     print k
# Out:
#   File "<ipython-input-86-69e6230dec3d>", line 3
#     #     print k
#                  ^
# IndentationError: expected an indented block

# %% [markdown]
# # Data Preprocessing

# %%
event_data = pd.read_csv("./data/event_data.csv")
line_up = pd.read_csv("./data/lineup.csv")
match_data = pd.read_csv("./data/match_data.csv")
match_data['match_id'] = match_data['temp_id']
match_data.drop('temp_id',axis=1,inplace=True)
event_data['match_id'] = event_data['join_id']
event_data.drop('join_id',axis=1,inplace=True)

# %%
event_data.head()
# Out:
#      id minute player_name  event_type event_datacol       match_id
# 0  1477    85'    G. Xhaka      Assist             H  1510524195220
# 1  1478    85'   O. Giroud        Goal             H  1510524195220
# 2  1479    83'    G. Xhaka      Assist             H  1510524195220
# 3  1480    83'   A. Ramsey        Goal             H  1510524195220
# 4  1481    75'  T. Walcott  D. Welbeck             H  1510524195220

# %%
# line_up.head()

# %%
match_data.head()
# Out:
#     id  week               home                  away     date  winner  score  \
# 0  107     1         Arsenal FC     Leicester City FC  8/11/17       1  4 - 3
# 1  108     1         Watford FC          Liverpool FC  8/12/17       0  3 - 3
# 2  109     1         Chelsea FC            Burnley FC  8/12/17      -1  2 - 3
# 3  110     1  Crystal Palace FC  Huddersfield Town FC  8/12/17      -1  0 - 3
# 4  111     1         Everton FC         Stoke City FC  8/12/17       1  1 - 0
#
#         match_id
# 0  1510524195220
# 1  1510524198580
# 2  1510524201480
# 3  1510524205545
# 4  1510524208824

# %%
# match_ids = list(set(minute_data.temp_id))
# matches = pd.DataFrame(data=match_ids,columns=['temp_id'])
minutes = pd.DataFrame(range(91),columns=['minute'])
match_data['dump'] = [1 for i in range(match_data.shape[0])]
minutes['dump'] = [1 for i in range(minutes.shape[0])]

match_data = pd.merge(match_data,minutes).drop('dump',axis=1)

# %%
event_data.dropna(inplace=True,axis=0, how= 'any')
event_data.minute = event_data.minute.astype("str")
for i,row in event_data.iterrows():
    if "+" in event_data.loc[i,('minute')]:
        event_data.loc[i,('minute')] = event_data.loc[i,('minute')][:2]
    else:
        event_data.loc[i,('minute')] = event_data.loc[i,('minute')][:-1]

event_data.minute = event_data.minute.astype("int")

# %%
# match_data['join_id'] = str(match_data['match_id'])+str(match_data['minute'])
# event_data['join_id'] = str(event_data['match_id'])+str(event_data['minute'])

# %%
# event_data.drop_duplicates(subset=["match_id", "minute"], keep='first', inplace=True)
event_data.sort_values(["match_id",'minute'],inplace=True)
event_data.head(10)
# Out:
#       id  minute     player_name event_type event_datacol       match_id
# 9   1486       2  Mohamed Elneny     Assist             H  1510524195220
# 10  1487       2    A. Lacazette       Goal             H  1510524195220
# 19  1496       5      S. Okazaki       Goal             A  1510524195220
# 20  1497       5      H. Maguire     Assist             A  1510524195220
# 17  1494      29   M. Albrighton     Assist             A  1510524195220
# 18  1495      29        J. Vardy       Goal             A  1510524195220
# 7   1484      45    S. Kolašinac     Assist             H  1510524195220
# 8   1485      45      D. Welbeck       Goal             H  1510524195220
# 15  1492      56       R. Mahrez     Assist             A  1510524195220
# 16  1493      56        J. Vardy       Goal             A  1510524195220

# %%
match_data.head(20)
# Out:
#      id  week        home               away     date  winner  score  \
# 0   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 1   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 2   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 3   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 4   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 5   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 6   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 7   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 8   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 9   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 10  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 11  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 12  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 13  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 14  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 15  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 16  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 17  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 18  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 19  107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
#
#          match_id  minute
# 0   1510524195220       0
# 1   1510524195220       1
# 2   1510524195220       2
# 3   1510524195220       3
# 4   1510524195220       4
# 5   1510524195220       5
# 6   1510524195220       6
# 7   1510524195220       7
# 8   1510524195220       8
# 9   1510524195220       9
# 10  1510524195220      10
# 11  1510524195220      11
# 12  1510524195220      12
# 13  1510524195220      13
# 14  1510524195220      14
# 15  1510524195220      15
# 16  1510524195220      16
# 17  1510524195220      17
# 18  1510524195220      18
# 19  1510524195220      19

# %%
minute_data = pd.merge(match_data,event_data,on=["match_id", "minute"],how='left')
# minute_data.dropna(inplace=True,axis=0, how= 'any')

# %%
minute_data.sort_values(["match_id",'minute'],inplace=True)

# %%
minute_data.head(10)
# Out:
#    id_x  week        home               away     date  winner  score  \
# 0   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 1   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 2   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 3   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 4   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 5   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 6   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 7   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 8   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
# 9   107     1  Arsenal FC  Leicester City FC  8/11/17       1  4 - 3
#
#         match_id  minute    id_y     player_name event_type event_datacol
# 0  1510524195220       0     NaN             NaN        NaN           NaN
# 1  1510524195220       1     NaN             NaN        NaN           NaN
# 2  1510524195220       2  1486.0  Mohamed Elneny     Assist             H
# 3  1510524195220       2  1487.0    A. Lacazette       Goal             H
# 4  1510524195220       3     NaN             NaN        NaN           NaN
# 5  1510524195220       4     NaN             NaN        NaN           NaN
# 6  1510524195220       5  1496.0      S. Okazaki       Goal             A
# 7  1510524195220       5  1497.0      H. Maguire     Assist             A
# 8  1510524195220       6     NaN             NaN        NaN           NaN
# 9  1510524195220       7     NaN             NaN        NaN           NaN

# %%
minute_data = minute_data[minute_data.event_type!='Assist']
minute_data.drop(["id_x", "id_y"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-53d93d6e6858> in <module>()
#       1 minute_data = minute_data[minute_data.event_type!='Assist']
# ----> 2 minute_data.drop(["id_x", "id_y"], axis=1, inplace=True)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['id_x' 'id_y'] not contained in axis

# %%
minute_data.reset_index(drop=True, inplace=True)

# %%
minute_data['H_Goal'] = 0
minute_data['A_Goal'] = 0
# minute_data['H_YC'] =

# %%
# minute_data.event_type.value_counts(dropna=True)
#

# %%
match_id = minute_data["match_id"][0]

for i, row in minute_data.iterrows():
    if row.minute == 0:
        continue
    
#     print row.minute
    
    if row.match_id != match_id:
        match_id = row.match_id
        
    
    if row.event_type in ['Goal', 'Penalty Goal']:
        if row.event_datacol == 'H':
            minute_data.loc[i, ("H_Goal")] = minute_data.loc[i-1, ("H_Goal")]+1
            minute_data.loc[i, ("A_Goal")] = minute_data.loc[i-1, ("A_Goal")]
            
        else:
            minute_data.loc[i, ("A_Goal")] = minute_data.loc[i-1, ("A_Goal")]+1
            minute_data.loc[i, ("H_Goal")] = minute_data.loc[i-1, ("H_Goal")]
    
    elif row.event_type == 'Own Goal':
        if row.event_datacol == 'A':
            minute_data.loc[i, ("H_Goal")] = minute_data.loc[i-1, ("H_Goal")]+1
            minute_data.loc[i, ("A_Goal")] = minute_data.loc[i-1, ("A_Goal")]
            
        else:
            minute_data.loc[i, ("A_Goal")] = minute_data.loc[i-1, ("A_Goal")]+1
            minute_data.loc[i, ("H_Goal")] = minute_data.loc[i-1, ("H_Goal")]
            
    else:
        minute_data.loc[i, ("H_Goal")] = minute_data.loc[i-1, ("H_Goal")]
        minute_data.loc[i, ("A_Goal")] = minute_data.loc[i-1, ("A_Goal")]

# %%
minute_data.tail(95)
# Out:
#       week               home                 away      date  winner  score  \
# 9126    10  Leicester City FC           Everton FC  10/29/17       1  2 - 0
# 9127    10  Leicester City FC           Everton FC  10/29/17       1  2 - 0
# 9128    10  Leicester City FC           Everton FC  10/29/17       1  2 - 0
# 9129    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9130    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9131    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9132    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9133    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9134    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9135    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9136    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9137    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9138    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9139    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9140    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9141    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9142    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9143    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9144    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9145    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9146    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9147    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9148    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9149    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9150    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9151    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9152    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9153    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9154    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9155    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# ...    ...                ...                  ...       ...     ...    ...
# 9191    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9192    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9193    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9194    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9195    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9196    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9197    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9198    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9199    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9200    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9201    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9202    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9203    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9204    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9205    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9206    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9207    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9208    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9209    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9210    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9211    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9212    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9213    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9214    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9215    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9216    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9217    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9218    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9219    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
# 9220    10         Burnley FC  Newcastle United FC  10/30/17       1  1 - 0
#
#            match_id  minute   player_name   event_type event_datacol  H_Goal  \
# 9126  1510524677238      88           NaN          NaN           NaN       2
# 9127  1510524677238      89           NaN          NaN           NaN       2
# 9128  1510524677238      90  K. Iheanacho     J. Vardy             H       2
# 9129  1510524680550       0           NaN          NaN           NaN       0
# 9130  1510524680550       1           NaN          NaN           NaN       0
# 9131  1510524680550       2           NaN          NaN           NaN       0
# 9132  1510524680550       3           NaN          NaN           NaN       0
# 9133  1510524680550       4           NaN          NaN           NaN       0
# 9134  1510524680550       5           NaN          NaN           NaN       0
# 9135  1510524680550       6           NaN          NaN           NaN       0
# 9136  1510524680550       7           NaN          NaN           NaN       0
# 9137  1510524680550       8           NaN          NaN           NaN       0
# 9138  1510524680550       9           NaN          NaN           NaN       0
# 9139  1510524680550      10           NaN          NaN           NaN       0
# 9140  1510524680550      11           NaN          NaN           NaN       0
# 9141  1510524680550      12           NaN          NaN           NaN       0
# 9142  1510524680550      13           NaN          NaN           NaN       0
# 9143  1510524680550      14           NaN          NaN           NaN       0
# 9144  1510524680550      15           NaN          NaN           NaN       0
# 9145  1510524680550      16           NaN          NaN           NaN       0
# 9146  1510524680550      17           NaN          NaN           NaN       0
# 9147  1510524680550      18           NaN          NaN           NaN       0
# 9148  1510524680550      19           NaN          NaN           NaN       0
# 9149  1510524680550      20           NaN          NaN           NaN       0
# 9150  1510524680550      21           NaN          NaN           NaN       0
# 9151  1510524680550      22           NaN          NaN           NaN       0
# 9152  1510524680550      23           NaN          NaN           NaN       0
# 9153  1510524680550      24           NaN          NaN           NaN       0
# 9154  1510524680550      25           NaN          NaN           NaN       0
# 9155  1510524680550      26           NaN          NaN           NaN       0
# ...             ...     ...           ...          ...           ...     ...
# 9191  1510524680550      62       J. Cork  Yellow Card             H       0
# 9192  1510524680550      63           NaN          NaN           NaN       0
# 9193  1510524680550      64           NaN          NaN           NaN       0
# 9194  1510524680550      65           NaN          NaN           NaN       0
# 9195  1510524680550      66           NaN          NaN           NaN       0
# 9196  1510524680550      67           NaN          NaN           NaN       0
# 9197  1510524680550      68           NaN          NaN           NaN       0
# 9198  1510524680550      69           NaN          NaN           NaN       0
# 9199  1510524680550      70           NaN          NaN           NaN       0
# 9200  1510524680550      71           NaN          NaN           NaN       0
# 9201  1510524680550      72           NaN          NaN           NaN       0
# 9202  1510524680550      73           NaN          NaN           NaN       0
# 9203  1510524680550      74   J. Hendrick         Goal             H       1
# 9204  1510524680550      75  J. Tarkowski  Yellow Card             H       1
# 9205  1510524680550      76   A. Westwood    S. Defour             H       1
# 9206  1510524680550      76     I. Hayden  Ayoze Pérez             A       1
# 9207  1510524680550      77           NaN          NaN           NaN       1
# 9208  1510524680550      78           NaN          NaN           NaN       1
# 9209  1510524680550      79  Jacob Murphy   M. Ritchie             A       1
# 9210  1510524680550      80           NaN          NaN           NaN       1
# 9211  1510524680550      81           NaN          NaN           NaN       1
# 9212  1510524680550      82           NaN          NaN           NaN       1
# 9213  1510524680550      83      D. Gayle     M. Diamé             A       1
# 9214  1510524680550      84           NaN          NaN           NaN       1
# 9215  1510524680550      85           NaN          NaN           NaN       1
# 9216  1510524680550      86           NaN          NaN           NaN       1
# 9217  1510524680550      87           NaN          NaN           NaN       1
# 9218  1510524680550      88           NaN          NaN           NaN       1
# 9219  1510524680550      89           NaN          NaN           NaN       1
# 9220  1510524680550      90           NaN          NaN           NaN       1
#
#       A_Goal
# 9126       0
# 9127       0
# 9128       0
# 9129       0
# 9130       0
# 9131       0
# 9132       0
# 9133       0
# 9134       0
# 9135       0
# 9136       0
# 9137       0
# 9138       0
# 9139       0
# 9140       0
# 9141       0
# 9142       0
# 9143       0
# 9144       0
# 9145       0
# 9146       0
# 9147       0
# 9148       0
# 9149       0
# 9150       0
# 9151       0
# 9152       0
# 9153       0
# 9154       0
# 9155       0
# ...      ...
# 9191       0
# 9192       0
# 9193       0
# 9194       0
# 9195       0
# 9196       0
# 9197       0
# 9198       0
# 9199       0
# 9200       0
# 9201       0
# 9202       0
# 9203       0
# 9204       0
# 9205       0
# 9206       0
# 9207       0
# 9208       0
# 9209       0
# 9210       0
# 9211       0
# 9212       0
# 9213       0
# 9214       0
# 9215       0
# 9216       0
# 9217       0
# 9218       0
# 9219       0
# 9220       0
#
# [95 rows x 13 columns]

# %%
minute_data[minute_data.event_type=='Own Goal']
# Out:
#       week                       home                  away      date  winner  \
# 299      1          Crystal Palace FC  Huddersfield Town FC   8/12/17      -1
# 718      1  Brighton & Hove Albion FC    Manchester City FC   8/12/17      -1
# 1737     2       Tottenham Hotspur FC            Chelsea FC   8/20/17      -1
# 6645     8          Crystal Palace FC            Chelsea FC  10/14/17       1
# 6773     8         Manchester City FC         Stoke City FC  10/14/17       1
# 7952     9           Swansea City AFC     Leicester City FC  10/21/17      -1
#
#       score       match_id  minute   player_name event_type event_datacol  \
# 299   0 - 3  1510524205545      23       J. Ward   Own Goal             H
# 718   0 - 2  1510524224492      75       L. Dunk   Own Goal             H
# 1737  1 - 2  1510524272597      82  M. Batshuayi   Own Goal             A
# 6645  2 - 1  1510524554906      11   Azpilicueta   Own Goal             A
# 6773  7 - 2  1510524557874      47     K. Walker   Own Goal             H
# 7952  1 - 2  1510524621545      24  F. Fernández   Own Goal             H
#
#       H_Goal  A_Goal
# 299        0       1
# 718        0       2
# 1737       1       1
# 6645       1       0
# 6773       3       2
# 7952       0       1

# %%
# train_data = minute_data[["match_id", "date", "minute", "H_Goal", "A_Goal", "winner"]]
